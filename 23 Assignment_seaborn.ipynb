# %%
'''Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.'''

import seaborn as sns


# Here are five common plots that can be created using the Seaborn library, along with their uses:

# 1. **Scatter Plot (`sns.scatterplot`)**:
# **Use**: Visualizes the relationship between two continuous variables. It is useful for identifying 
# correlations, trends, and outliers.


sns.scatterplot(x='total_bill', y='tip', data=tips)


# 2. **Box Plot (`sns.boxplot`)**:
# **Use**: Displays the distribution of a dataset based on a five-number summary 
# (minimum, first quartile, median, third quartile, and maximum). It helps in identifying 
# outliers and understanding the spread and skewness of the data.


sns.boxplot(x='day', y='total_bill', data=tips)



# 3. **Histogram (`sns.histplot`)**:
#**Use**: Shows the distribution of a single continuous variable by dividing the data 
# into bins and counting the number of observations in each bin. It is useful for understanding 
# the frequency distribution of the data.


sns.histplot(tips['total_bill'], bins=10)
  

# 4. **Heatmap (`sns.heatmap`)**:
# **Use**: Represents data in a matrix form with colors indicating the values. It is particularly 
# useful for visualizing the correlation matrix and highlighting relationships between variables.
 
sns.heatmap(tips.corr(), annot=True, cmap='coolwarm')
 

# 5. **Pair Plot (`sns.pairplot`)**:
# **Use**: Plots pairwise relationships in a dataset, including scatter plots for numerical 
# variables and histograms or KDE plots for the diagonal. It is useful for exploring relationships 
# between multiple variables simultaneously.
  
sns.pairplot(tips)
  

# These plots provide various ways to visualize data and uncover insights, making Seaborn a  
# powerful tool for data analysis.

# %%
'''Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions.'''

import seaborn as sns

fmri = sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

sns.lineplot(x = 'timepoint' , y = 'signal', data=fmri)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
'''Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'.'''

import seaborn as sns 
import matplotlib.pyplot as plt
import pandas 

titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
fig,axes = plt.subplots(1,2 , figsize = (15,5))

sns.boxplot( x = 'pclass' , y = 'age' , data=titanic, ax=axes[0])
axes[0].set_title('box plot of age by pclass')

sns.boxplot(x="pclass" , y='fare', data=titanic, ax = axes[1])
axes[1].set_title(" box plot of fare by pclass")
# Out:
# Text(0.5, 1.0, ' box plot of fare by pclass')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Box plot for pclass vs age
sns.boxplot(x='pclass', y='age', data=titanic, ax=axes[0])
axes[0].set_title('Box plot of Age by Pclass')

# Box plot for pclass vs fare
sns.boxplot(x='pclass', y='fare', data=titanic, ax=axes[1])
axes[1].set_title('Box plot of Fare by Pclass')

# Show the plots
plt.tight_layout()
plt.show()

# %%
'''Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset.'''


diamond = sns.load_dataset("diamonds")
diamond

sns.histplot(x=diamond.price  , data=diamond, hue='cut')
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
'''Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset.'''

iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=iris ,hue='species')
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
'''Que 6: Use the "flights" dataset from seaborn to plot a heatmap.'''
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# create a matrix of the data 

flights_pivot = flights.pivot(index='year', columns='month',values='passengers')
flights_pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
plt.figure(figsize=(8,6))  # small data -> (5,4),(8,6),(10,8),(12,10)

sns.heatmap(flights_pivot,annot=True,cmap='YlGnBu',fmt="d")  #cmap used for colors 

'''fmt="d": This means that the annotations will be formatted as decimal integers. It’s used when your data consists 
of whole numbers and you want to display them as such.'''
# Out:
# 'fmt="d": This means that the annotations will be formatted as decimal integers. It’s used when your data consists \nof whole numbers and you want to display them as such.'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
flights = sns.load_dataset('flights')

# Pivot the dataset to create a matrix
flights_pivot = flights.pivot(index='year', columns='month', values='passengers')

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(flights_pivot, annot=True, fmt="d", cmap='YlGnBu')

# Display the plot
plt.show()
